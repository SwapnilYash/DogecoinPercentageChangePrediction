# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-797129ce-b013-47af-a43a-7ad3991066f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-797129ce-b013-47af-a43a-7ad3991066f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prediction_data.csv to prediction_data.csv

# %%
dataset = pd.read_csv('prediction_data.csv')

# %%
dataset
# Out:
#           Date  Sentiment Score  ...       Vol  Percentage Change
# 0   2019-04-02           0.8176  ...   0.06020              25.50
# 1   2019-04-03           0.3400  ...   0.08980              11.66
# 2   2019-04-03           0.0000  ...   0.08980              11.66
# 3   2019-04-03           0.0000  ...   0.08980              11.66
# 4   2020-04-25           0.0000  ...   0.17312               1.98
# 5   2020-07-18           0.1511  ...   8.33000              13.19
# 6   2020-11-18           0.0000  ...   1.02000              -1.06
# 7   2020-12-20           0.0000  ...  10.00000              18.16
# 8   2021-02-04           0.0721  ...  48.78000              41.69
# 9   2021-02-04           0.0000  ...  48.78000              41.69
# 10  2021-02-04           0.0000  ...  48.78000              41.69
# 11  2021-02-08          -0.3291  ...  26.40000               0.09
# 12  2021-02-08           0.0000  ...  26.40000               0.09
# 13  2021-02-10           0.0000  ...  14.16000               3.71
# 14  2021-02-12          -0.2732  ...   7.52000               0.12
# 15  2021-02-15           0.3182  ...  11.32000             -10.01
# 16  2021-02-15           0.4019  ...  11.32000             -10.01
# 17  2021-02-20           0.5106  ...   7.36000              -1.43
# 18  2021-02-20           0.6652  ...   7.36000              -1.43
# 19  2021-02-22           0.0000  ...   8.42000              -4.09
# 20  2021-03-02           0.0000  ...   2.38000              -0.41
# 21  2021-03-02          -0.5106  ...   2.38000              -0.41
# 22  2021-03-03           0.0000  ...   1.84000               0.26
# 23  2021-03-06           0.0000  ...   2.75000               2.87
# 24  2021-03-14          -0.3612  ...   5.15000              -6.74
# 25  2021-03-14           0.0000  ...   5.15000              -6.74
# 26  2021-03-16           0.0000  ...   2.00000               2.89
# 27  2021-03-19           0.0000  ...   1.69000               1.72
# 28  2021-04-01           0.0000  ...  15.24000              15.51
# 29  2021-04-15           0.0000  ...  24.61000              50.63
# 30  2021-04-15           0.0000  ...  24.61000              50.63
# 31  2021-05-10           0.0000  ...   9.68000             -20.81
# 32  2021-05-11           0.4404  ...   7.55000               9.67
# 33  2021-05-14           0.7964  ...  10.63000              15.03
# 34  2021-05-16          -0.0516  ...   5.38000               1.26
# 35  2021-05-16          -0.2960  ...   5.38000               1.26
# 36  2021-05-16           0.1779  ...   5.38000               1.26
# 37  2021-05-20           0.2960  ...   8.53000              20.24
# 38  2021-05-20           0.2732  ...   8.53000              20.24
# 39  2021-05-20           0.0000  ...   8.53000              20.24
# 40  2021-05-25           0.0000  ...   3.71000              -5.07
# 41  2021-05-25           0.7579  ...   3.71000              -5.07
# 42  2021-05-25           0.8834  ...   3.71000              -5.07
# 43  2021-05-26          -0.1082  ...   2.39000               2.04
# 44  2021-06-05           0.6908  ...   2.40000              -1.21
# 45  2021-07-01           0.0000  ...   2.25000              -3.78
# 46  2021-07-01           0.0000  ...   2.25000              -3.78
# 47  2021-07-02          -0.1531  ...   1.08000               0.27
# 48  2021-07-09           0.5719  ...   2.29000               5.74
# 49  2021-07-13           0.0000  ...   0.95327              -2.02
# 50  2021-07-14           0.0000  ...   1.25000              -1.09
# 51  2021-07-14           0.0000  ...   1.25000              -1.09
# 52  2021-07-17           0.7088  ...   2.57000               8.30
#
# [53 rows x 8 columns]

# %%
X = dataset[["Sentiment Score"]]
y = dataset[["Percentage Change"]]

# %%
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X)

# %%
plt.scatter(X, y, color = 'blue')
plt.plot(X, regressor.predict(X), color = 'orange')
plt.title('% change vs senti score')
plt.xlabel('% change')
plt.ylabel('senti score')
plt.show()
